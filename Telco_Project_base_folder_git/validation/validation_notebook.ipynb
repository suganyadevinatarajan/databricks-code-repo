-- %%
%python
gold_fact_table = "telecom_gold.fact_wide_cdr"
gold_aggr_table = "telecom_gold.fact_realtime_customer_aggr"
dim_tower_scd1 = "telecom_gold.dim_towers_gold_scd1"
dim_device_scd1 = "telecom_gold.dim_device_gold_scd1"
dim_tower_scd2 = "telecom_gold.dim_towers_gold_scd2"
dim_device_scd2 = "telecom_gold.dim_device_gold_scd2"
display(spark.read.table(gold_fact_table))
display(spark.read.table(gold_aggr_table))

-- %%
%sql
select * from telecom_bronze.bronze_dim_tower

-- %%
%sql
select * from telecom_silver.dim_tower_silver1

-- %%
%sql
select * from telecom_gold.dim_tower_gold_scd1

-- %%
%sql
select * from telecom_gold.dim_tower_gold_scd2

-- %%
%sql
drop table telecom_bronze.bronze_dim_tower;
drop table telecom_silver.silver_dim_tower;
drop table telecom_gold.dim_tower_gold_scd1;
drop table telecom_gold.dim_tower_gold_scd2;
