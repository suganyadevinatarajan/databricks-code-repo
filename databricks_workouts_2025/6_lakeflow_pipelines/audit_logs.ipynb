# %%
# %sql
--drop table if exists catalog1_we47.schema1_we47.audit_log;
create table if not exists catalog2_we47.schema2_we47.audit_log(
  id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
  message string,loadts timestamp)
using delta;

# %%
# %sql
insert into catalog2_we47.schema2_we47.audit_log(message,loadts) values('No data in the source DB table',current_timestamp);

# %%
# %sql
select * from catalog2_we47.schema2_we47.audit_log
