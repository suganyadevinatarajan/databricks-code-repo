# %%
# %sql
CREATE TABLE IF NOT EXISTS catalog1_dropme.schema1_dropme.bronze_shipments1
USING DELTA
AS SELECT
  shipment_id,
  first_name,
  last_name,
  age,
  role,
  updated_at,
  city
FROM gcp_mysql_fc_we471.logistics.shipments1;

# %%
# %sql
insert overwrite table catalog1_dropme.schema1_dropme.bronze_shipments1
SELECT * FROM gcp_mysql_fc_we471.logistics.shipments1 
  WHERE updated_at > (SELECT COALESCE(MAX(updated_at), '1970-01-01') FROM catalog1_dropme.schema1_dropme.bronze_shipments1);
