# %%
# %py
import requests as s
input=s.get( "https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
print(input.text)
dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",input.text,overwrite=True)
