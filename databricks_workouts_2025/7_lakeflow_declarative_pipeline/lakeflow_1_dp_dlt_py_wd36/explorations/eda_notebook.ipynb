# %%
# %sql
select * from catalog1_we47.default.drugstbl_medal_bronze3 where uniqueid in (10000013,10000012)

# %%
# %sql
--select * from lakehousecat.deltadb.drugstbl
--5,690 rows
insert into lakehousecat.deltadb.drugstbl(uniqueid,drugname,rating) values(10000013,'abc',10);
update lakehousecat.deltadb.drugstbl set drugname='xyzz' where uniqueid=10000012;

# %%
# %sql
select * from catalog1_we47.schema1_we47.shipment1_bronze1

# %%
from pyspark import pipelines

@pipelines.table(name="lakehousecat.deltadb.drugstbl")#it becomes declarative by specifying decorator on top of the function
def load_data_bronze_imp_dp():#Imperative program
    df1=spark.readStream.table("lakehousecat.deltadb.drugstbl")#readStream will only
    df2=df1.filter("city is null")
    return df2

# %%
# %python
#Pure Pyspark DSL (Imperative because I didn't used decorator of pipelines offerred by Databricks) 
def load_data_bronze_imp_dp():#Imperative program
    df1=spark.read.table("gcp_mysql_fc_wd361.logistics.shipments1")
    df2=df1.filter("city is null")
    return df2

load_data_bronze_imp_dp().show(200)
#load_data_bronze_imp_dp().write.saveAsTable("lakehousecat.default.shipment1_bronze")

# %%
# %sql
select * from catalog1_we47.schema1_we47.shipment1_bronze1

# %%
# %sql
select * from gcp_mysql_fc_wd36.logistics.shipments1
